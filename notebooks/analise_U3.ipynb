# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.colors import to_rgba

# %%
# Lista de caminhos dos arquivos CSV
csv_file_paths_despesas_contratadas = [
    "../dados/despesas_contratadas_2022/despesas_contratadas_candidatos_2022_BRASIL.csv",
    "../dados/despesas_contratadas_2018/despesas_contratadas_candidatos_2018_BRASIL.csv"
]

# Lista para armazenar os DataFrames temporários
dataframes = []

# Loop para carregar cada arquivo e adicionar uma coluna de origem
for path in csv_file_paths_despesas_contratadas:
    # Nome único para indicar a origem dos dados
    file_name = path.split('/')[-1].replace('.csv', '')
    df = pd.read_csv(path, sep=';', encoding='latin1')
    df['origem'] = file_name  # Adiciona coluna indicando a origem
    dataframes.append(df)  # Adiciona o DataFrame à lista

# Combinar todos os DataFrames em um único DataFrame
df_despesas_contratadas_brasil = pd.concat(dataframes, ignore_index=True)

# Exibir as primeiras linhas do DataFrame combinado
df_despesas_contratadas_brasil.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  \
# 0  03/12/2024   01:02:19         2022                2       Ordinária
# 1  03/12/2024   01:02:19         2022                2       Ordinária
# 2  03/12/2024   01:02:19         2022                2       Ordinária
# 3  03/12/2024   01:02:19         2022                2       Ordinária
# 4  03/12/2024   01:02:19         2022                2       Ordinária
#
#    CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  ST_TURNO  \
# 0         546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 1         546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 2         546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 3         546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 4         546  Eleições Gerais Estaduais 2022  02/10/2022         1
#
#   TP_PRESTACAO_CONTAS  ... NM_PARTIDO_FORNECEDOR  DS_TIPO_DOCUMENTO  \
# 0               Final  ...                 #NULO        Nota Fiscal
# 1               Final  ...                 #NULO        Nota Fiscal
# 2               Final  ...                 #NULO        Nota Fiscal
# 3               Final  ...                 #NULO             Recibo
# 4               Final  ...                 #NULO              Outro
#
#   NR_DOCUMENTO CD_ORIGEM_DESPESA              DS_ORIGEM_DESPESA  SQ_DESPESA  \
# 0        14677          20150000                    Alimentação    50076228
# 1        15547          20150000                    Alimentação    50076460
# 2        12858          20150000                    Alimentação    50076554
# 3            1          20150000                    Alimentação    52273322
# 4           SN          20600000  Cessão ou locação de veículos    50895976
#
#    DT_DESPESA                          DS_DESPESA  VR_DESPESA_CONTRATADA  \
# 0  22/08/2022            FORNECIMENTO DE MARMITEX                2754,00
# 1  30/09/2022            FORNECIMENTO DE MARMITEX                1037,00
# 2  19/08/2022            FORNECIMENTO DE MARMITEX                3740,00
# 3  14/09/2022                            REFEIÇÃO                  72,00
# 4  01/09/2022  LOC.DE VEÍCULO CHEV/ONIX 10TMT LT1                2000,00
#
#                                         origem
# 0  despesas_contratadas_candidatos_2022_BRASIL
# 1  despesas_contratadas_candidatos_2022_BRASIL
# 2  despesas_contratadas_candidatos_2022_BRASIL
# 3  despesas_contratadas_candidatos_2022_BRASIL
# 4  despesas_contratadas_candidatos_2022_BRASIL
#
# [5 rows x 54 columns]

# %%
# Lista de caminhos dos arquivos CSV
csv_file_paths_despesas_pagas = [
    "../dados/despesas_pagas_2018/despesas_pagas_candidatos_2018_BRASIL.csv",
    "../dados/despesas_pagas_2022/despesas_pagas_candidatos_2022_BRASIL.csv"
]

# Lista para armazenar os DataFrames temporários
dataframes = []

# Loop para carregar cada arquivo e adicionar uma coluna de origem
for path in csv_file_paths_despesas_pagas:
    # Nome único para indicar a origem dos dados
    file_name = path.split('/')[-1].replace('.csv', '')
    df = pd.read_csv(path, sep=';', encoding='latin1')
    df['origem'] = file_name  # Adiciona coluna indicando a origem
    dataframes.append(df)  # Adiciona o DataFrame à lista

# Combinar todos os DataFrames em um único DataFrame
df_despesas_pagas_brasil = pd.concat(dataframes, ignore_index=True)

# Exibir as primeiras linhas do DataFrame combinado
df_despesas_pagas_brasil.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  \
# 0  01/12/2024   09:00:43         2018                2       Ordinária
# 1  01/12/2024   09:00:43         2018                2       Ordinária
# 2  01/12/2024   09:00:43         2018                2       Ordinária
# 3  01/12/2024   09:00:43         2018                2       Ordinária
# 4  01/12/2024   09:00:43         2018                2       Ordinária
#
#    CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  ST_TURNO  \
# 0         297  Eleições Gerais Estaduais 2018  07/10/2018         1
# 1         297  Eleições Gerais Estaduais 2018  07/10/2018         1
# 2         297  Eleições Gerais Estaduais 2018  07/10/2018         1
# 3         297  Eleições Gerais Estaduais 2018  07/10/2018         1
# 4         297  Eleições Gerais Estaduais 2018  07/10/2018         1
#
#   TP_PRESTACAO_CONTAS  ... CD_NATUREZA_DESPESA  DS_NATUREZA_DESPESA  \
# 0               Final  ...                   1           Financeiro
# 1               Final  ...                   1           Financeiro
# 2               Final  ...                   1           Financeiro
# 3               Final  ...                   1           Financeiro
# 4               Final  ...                   1           Financeiro
#
#   CD_ESPECIE_RECURSO DS_ESPECIE_RECURSO SQ_DESPESA  SQ_PARCELAMENTO_DESPESA  \
# 0                  0             Cheque   23369592                 15499287
# 1                  0             Cheque   22825002                 14910990
# 2                  0             Cheque   23859464                 16002925
# 3                  0             Cheque   23859464                 16002926
# 4                  0             Cheque   25004715                 17213991
#
#   DT_PAGTO_DESPESA                                      DS_DESPESA  \
# 0       27/08/2018      LOCAÇÃO DE IMOVEL PARA ATIVIDADE ELEITORAL
# 1       01/10/2018    LOCAÇÃO DE SALÃO DE EVENTOS PARA UMA REUNIÃO
# 2       15/10/2018    PAG DE ALUGUEL DO PERÍODO 11/08 A 10/09/2018
# 3       12/09/2018    PAG DE ALUGUEL DO PERÍODO 11/08 A 10/09/2018
# 4       12/09/2018  IMOVEL ALUGADO PARA SERVIR DE COMITE ELEITORAL
#
#   VR_PAGTO_DESPESA                                 origem
# 0           200,00  despesas_pagas_candidatos_2018_BRASIL
# 1           100,00  despesas_pagas_candidatos_2018_BRASIL
# 2          8000,00  despesas_pagas_candidatos_2018_BRASIL
# 3          4000,00  despesas_pagas_candidatos_2018_BRASIL
# 4          5000,00  despesas_pagas_candidatos_2018_BRASIL
#
# [5 rows x 29 columns]

# %%
# Lista de caminhos dos arquivos CSV
csv_file_paths_despesas_receitas = [
    "../dados/receitas_2018/receitas_candidatos_2018_BRASIL.csv",
    "../dados/receitas_2022/receitas_candidatos_2022_BRASIL.csv"
]

# Lista para armazenar os DataFrames temporários
dataframes = []

# Loop para carregar cada arquivo e adicionar uma coluna de origem
for path in csv_file_paths_despesas_receitas:
    # Nome único para indicar a origem dos dados
    file_name = path.split('/')[-1].replace('.csv', '')
    df = pd.read_csv(path, sep=';', encoding='latin1')
    df['origem'] = file_name  # Adiciona coluna indicando a origem
    dataframes.append(df)  # Adiciona o DataFrame à lista

# Combinar todos os DataFrames em um único DataFrame
df_despesas_receitas_brasil = pd.concat(dataframes, ignore_index=True)

# Exibir as primeiras linhas do DataFrame combinado
df_despesas_receitas_brasil.head()
# Out:
# /tmp/ipykernel_89/1192152535.py:14: DtypeWarning: Columns (39,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, sep=';', encoding='latin1')
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  \
# 0  01/12/2024   09:04:26         2018                2       ORDINÁRIA
# 1  01/12/2024   09:04:26         2018                2       ORDINÁRIA
# 2  01/12/2024   09:04:26         2018                2       ORDINÁRIA
# 3  01/12/2024   09:04:26         2018                2       ORDINÁRIA
# 4  01/12/2024   09:04:26         2018                2       ORDINÁRIA
#
#    CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  ST_TURNO  \
# 0         297  Eleições Gerais Estaduais 2018  07/10/2018         1
# 1         297  Eleições Gerais Estaduais 2018  07/10/2018         1
# 2         297  Eleições Gerais Estaduais 2018  07/10/2018         1
# 3         297  Eleições Gerais Estaduais 2018  07/10/2018         1
# 4         297  Eleições Gerais Estaduais 2018  07/10/2018         1
#
#   TP_PRESTACAO_CONTAS  ...       NR_RECIBO_DOACAO  NR_DOCUMENTO_DOACAO  \
# 0               FINAL  ...  431110700000AC000010E          51920301291
# 1               FINAL  ...  431110700000AC000005E               #NULO#
# 2               FINAL  ...  431110700000AC000001E                   01
# 3               FINAL  ...  430000700000AC000005E               #NULO#
# 4               FINAL  ...  430000700000AC000007E            235902359
#
#   SQ_RECEITA  DT_RECEITA                                   DS_RECEITA  \
# 0   11839873  23/10/2018                                        #NULO
# 1   11839872  15/08/2018  DOAÇÃO DE PRESTAÇÃO DE SERVIÇOS NA CAMPANHA
# 2   11839867  22/08/2018                                        #NULO
# 3   11840314  29/09/2018                              GASOMLINA COMUM
# 4   11840311  28/09/2018                                        #NULO
#
#    VR_RECEITA     DS_NATUREZA_RECURSO_ESTIMAVEL  DS_GENERO  DS_COR_RACA  \
# 0       13,20                             #NULO  Masculino       Branca
# 1     1000,00  Serviços prestados por terceiros  Masculino       Branca
# 2    15000,00                             #NULO  Masculino       Branca
# 3      321,65      Combustíveis e lubrificantes   Feminino        Parda
# 4     1500,00                             #NULO   Feminino        Parda
#
#                             origem
# 0  receitas_candidatos_2018_BRASIL
# 1  receitas_candidatos_2018_BRASIL
# 2  receitas_candidatos_2018_BRASIL
# 3  receitas_candidatos_2018_BRASIL
# 4  receitas_candidatos_2018_BRASIL
#
# [5 rows x 61 columns]

# %%
# Identificar valores duplicados em anos diferentes
duplicados = (
    df_despesas_contratadas_brasil.groupby('SQ_CANDIDATO')['ANO_ELEICAO']
    .nunique()  # Conta o número de anos únicos para cada nome
    .reset_index()  # Reseta o índice para facilitar a visualização
)

# Filtrar nomes que aparecem em mais de um ano
valores_repetidos = duplicados[duplicados['ANO_ELEICAO'] > 1]

print("Valores que aparecem em anos diferentes:")
print(valores_repetidos)
# Out:
# Valores que aparecem em anos diferentes:
# Empty DataFrame
# Columns: [SQ_CANDIDATO, ANO_ELEICAO]
# Index: []

# %%
# Identificar valores duplicados em anos diferentes
duplicados = (
    df_despesas_pagas_brasil.groupby('SQ_PRESTADOR_CONTAS')['ANO_ELEICAO']
    .nunique()  # Conta o número de anos únicos para cada nome
    .reset_index()  # Reseta o índice para facilitar a visualização
)

# Filtrar nomes que aparecem em mais de um ano
valores_repetidos = duplicados[duplicados['ANO_ELEICAO'] > 1]

print("Valores que aparecem em anos diferentes:")
print(valores_repetidos)
# Out:
# Valores que aparecem em anos diferentes:
# Empty DataFrame
# Columns: [SQ_PRESTADOR_CONTAS, ANO_ELEICAO]
# Index: []

# %%
# Identificar valores duplicados em anos diferentes
duplicados = (
    df_despesas_receitas_brasil.groupby('SQ_CANDIDATO')['ANO_ELEICAO']
    .nunique()  # Conta o número de anos únicos para cada nome
    .reset_index()  # Reseta o índice para facilitar a visualização
)

# Filtrar nomes que aparecem em mais de um ano
valores_repetidos = duplicados[duplicados['ANO_ELEICAO'] > 1]

print("Valores que aparecem em anos diferentes:")
print(valores_repetidos)
# Out:
# Valores que aparecem em anos diferentes:
# Empty DataFrame
# Columns: [SQ_CANDIDATO, ANO_ELEICAO]
# Index: []

# %%
df_filtrado = df_despesas_contratadas_brasil[['DS_ELEICAO', 'SG_UF', 'ANO_ELEICAO', 'ST_TURNO', 'SQ_PRESTADOR_CONTAS', 'SQ_DESPESA', 'DS_TIPO_DOCUMENTO', 'DT_DESPESA', 'DS_DESPESA', 'VR_DESPESA_CONTRATADA']]
df_filtrado.head()
# Out:
#                        DS_ELEICAO SG_UF  ANO_ELEICAO  ST_TURNO  \
# 0  Eleições Gerais Estaduais 2022    AC         2022         1
# 1  Eleições Gerais Estaduais 2022    AC         2022         1
# 2  Eleições Gerais Estaduais 2022    AC         2022         1
# 3  Eleições Gerais Estaduais 2022    AC         2022         1
# 4  Eleições Gerais Estaduais 2022    AC         2022         1
#
#    SQ_PRESTADOR_CONTAS  SQ_DESPESA DS_TIPO_DOCUMENTO  DT_DESPESA  \
# 0           3783868250    50076228       Nota Fiscal  22/08/2022
# 1           3783868250    50076460       Nota Fiscal  30/09/2022
# 2           3783868250    50076554       Nota Fiscal  19/08/2022
# 3           3790198924    52273322            Recibo  14/09/2022
# 4           3780998777    50895976             Outro  01/09/2022
#
#                            DS_DESPESA VR_DESPESA_CONTRATADA
# 0            FORNECIMENTO DE MARMITEX               2754,00
# 1            FORNECIMENTO DE MARMITEX               1037,00
# 2            FORNECIMENTO DE MARMITEX               3740,00
# 3                            REFEIÇÃO                 72,00
# 4  LOC.DE VEÍCULO CHEV/ONIX 10TMT LT1               2000,00

# %%
df_filtrado.dtypes
# Out:
# DS_ELEICAO               object
# SG_UF                    object
# ANO_ELEICAO               int64
# ST_TURNO                  int64
# SQ_PRESTADOR_CONTAS       int64
# SQ_DESPESA                int64
# DS_TIPO_DOCUMENTO        object
# DT_DESPESA               object
# DS_DESPESA               object
# VR_DESPESA_CONTRATADA    object
# dtype: object

# %%
df_filtrado['VR_DESPESA_CONTRATADA'] = df_filtrado['VR_DESPESA_CONTRATADA'].str.replace(',', '.').astype('float')
# Out:
# /tmp/ipykernel_89/4042171819.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['VR_DESPESA_CONTRATADA'] = df_filtrado['VR_DESPESA_CONTRATADA'].str.replace(',', '.').astype('float')

# %%
df_filtrado['DT_DESPESA'] = pd.to_datetime(df_filtrado['DT_DESPESA'])
# Out:
# /tmp/ipykernel_89/2572153538.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_filtrado['DT_DESPESA'] = pd.to_datetime(df_filtrado['DT_DESPESA'])
# /tmp/ipykernel_89/2572153538.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['DT_DESPESA'] = pd.to_datetime(df_filtrado['DT_DESPESA'])

# %%
df_filtrado2 = df_despesas_pagas_brasil[['DS_ELEICAO', 'SG_UF', 'ANO_ELEICAO', 'ST_TURNO', 'SQ_PRESTADOR_CONTAS', 'SQ_DESPESA', 'DS_FONTE_DESPESA']]
df_filtrado2.head()
# Out:
#                        DS_ELEICAO SG_UF  ANO_ELEICAO  ST_TURNO  \
# 0  Eleições Gerais Estaduais 2018    AC         2018         1
# 1  Eleições Gerais Estaduais 2018    AC         2018         1
# 2  Eleições Gerais Estaduais 2018    AC         2018         1
# 3  Eleições Gerais Estaduais 2018    AC         2018         1
# 4  Eleições Gerais Estaduais 2018    AC         2018         1
#
#    SQ_PRESTADOR_CONTAS  SQ_DESPESA  \
# 0            420242246    23369592
# 1            427249207    22825002
# 2            417251907    23859464
# 3            417251907    23859464
# 4            427249211    25004715
#
#                               DS_FONTE_DESPESA
# 0                              Outros Recursos
# 1  Fundo Especial de Financiamento de Campanha
# 2                              Outros Recursos
# 3                             Fundo Partidário
# 4  Fundo Especial de Financiamento de Campanha

# %%
df_filtrado3 = df_despesas_receitas_brasil[['DS_ELEICAO', 'SG_UF', 'ANO_ELEICAO', 'ST_TURNO', 'SQ_PRESTADOR_CONTAS', 'DS_GENERO']]
df_filtrado3.head()
# Out:
#                        DS_ELEICAO SG_UF  ANO_ELEICAO  ST_TURNO  \
# 0  Eleições Gerais Estaduais 2018    AC         2018         1
# 1  Eleições Gerais Estaduais 2018    AC         2018         1
# 2  Eleições Gerais Estaduais 2018    AC         2018         1
# 3  Eleições Gerais Estaduais 2018    AC         2018         1
# 4  Eleições Gerais Estaduais 2018    AC         2018         1
#
#    SQ_PRESTADOR_CONTAS  DS_GENERO
# 0            402109553  Masculino
# 1            402109553  Masculino
# 2            402109553  Masculino
# 3            402109554   Feminino
# 4            402109554   Feminino

# %%
# Criar um dicionário de mapeamento
mapeamento1 = dict(zip(df_filtrado2['SQ_DESPESA'], df_filtrado2['DS_FONTE_DESPESA']))

# Mapear os valores da coluna 'codigo' em df_a para 'descricao'
df_filtrado['DS_FONTE_DESPESA'] = df_filtrado['SQ_DESPESA'].map(mapeamento1)
# Out:
# /tmp/ipykernel_89/1787662309.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['DS_FONTE_DESPESA'] = df_filtrado['SQ_DESPESA'].map(mapeamento1)

# %%
# Criar um dicionário de mapeamento
mapeamento2 = dict(zip(df_filtrado3['SQ_PRESTADOR_CONTAS'], df_filtrado3['DS_GENERO']))

# Mapear os valores da coluna 'codigo' em df_a para 'descricao'
df_filtrado['DS_GENERO'] = df_filtrado['SQ_PRESTADOR_CONTAS'].map(mapeamento2)
# Out:
# /tmp/ipykernel_89/3063943009.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['DS_GENERO'] = df_filtrado['SQ_PRESTADOR_CONTAS'].map(mapeamento2)

# %%
df_filtrado
# Out:
#                              DS_ELEICAO SG_UF  ANO_ELEICAO  ST_TURNO  \
# 0        Eleições Gerais Estaduais 2022    AC         2022         1
# 1        Eleições Gerais Estaduais 2022    AC         2022         1
# 2        Eleições Gerais Estaduais 2022    AC         2022         1
# 3        Eleições Gerais Estaduais 2022    AC         2022         1
# 4        Eleições Gerais Estaduais 2022    AC         2022         1
# ...                                 ...   ...          ...       ...
# 3926223  Eleições Gerais Estaduais 2018    TO         2018         1
# 3926224  Eleições Gerais Estaduais 2018    TO         2018         1
# 3926225  Eleições Gerais Estaduais 2018    TO         2018         1
# 3926226  Eleições Gerais Estaduais 2018    TO         2018         1
# 3926227  Eleições Gerais Estaduais 2018    TO         2018         1
#
#          SQ_PRESTADOR_CONTAS  SQ_DESPESA DS_TIPO_DOCUMENTO DT_DESPESA  \
# 0                 3783868250    50076228       Nota Fiscal 2022-08-22
# 1                 3783868250    50076460       Nota Fiscal 2022-09-30
# 2                 3783868250    50076554       Nota Fiscal 2022-08-19
# 3                 3790198924    52273322            Recibo 2022-09-14
# 4                 3780998777    50895976             Outro 2022-09-01
# ...                      ...         ...               ...        ...
# 3926223            422504721    24811288             Outro 2018-09-14
# 3926224            424856731    24210090       Nota Fiscal 2018-09-16
# 3926225            422818074    24869348             Outro 2018-09-01
# 3926226            422818038    23822780             Outro 2018-09-12
# 3926227            422504730    24604527             Outro 2018-09-18
#
#                                      DS_DESPESA  VR_DESPESA_CONTRATADA  \
# 0                      FORNECIMENTO DE MARMITEX                 2754.0
# 1                      FORNECIMENTO DE MARMITEX                 1037.0
# 2                      FORNECIMENTO DE MARMITEX                 3740.0
# 3                                      REFEIÇÃO                   72.0
# 4            LOC.DE VEÍCULO CHEV/ONIX 10TMT LT1                 2000.0
# ...                                         ...                    ...
# 3926223  COORDENADOR DE CAMPANHA ELEITORAL 2018                 1500.0
# 3926224                  DESPESA COM HOSPEDAGEM                 1400.0
# 3926225             SERVIÇO DE EDITOR DE VIDEOS                 3000.0
# 3926226                SERVIÇOS ADMINISTRATIVOS                  800.0
# 3926227   DISTRIBUIÇÃO DE MATERIAIS DE CAMPANHA                  250.0
#
#                                     DS_FONTE_DESPESA  DS_GENERO
# 0        Fundo Especial de Financiamento de Campanha  Masculino
# 1        Fundo Especial de Financiamento de Campanha  Masculino
# 2        Fundo Especial de Financiamento de Campanha  Masculino
# 3                                   Fundo Partidário  Masculino
# 4        Fundo Especial de Financiamento de Campanha  Masculino
# ...                                              ...        ...
# 3926223                              Outros Recursos  Masculino
# 3926224  Fundo Especial de Financiamento de Campanha  Masculino
# 3926225  Fundo Especial de Financiamento de Campanha   Feminino
# 3926226                              Outros Recursos  Masculino
# 3926227                              Outros Recursos  Masculino
#
# [3926228 rows x 12 columns]

# %%
analise_total_fonte_despesa_distintos = df_filtrado['DS_FONTE_DESPESA'].nunique()
analise_valores_fonte_despesa_distintos = df_filtrado['DS_FONTE_DESPESA'].unique()

print(f"Total de valores distintos: {analise_total_fonte_despesa_distintos}")
print("Valores distintos:", analise_valores_fonte_despesa_distintos)
# Out:
# Total de valores distintos: 3
# Valores distintos: ['Fundo Especial de Financiamento de Campanha' 'Fundo Partidário'
#  'Outros Recursos' nan]

# %%
df_data = df_filtrado[df_filtrado['DT_DESPESA'].dt.year == 2022]

# Conta o número de dias distintos
total_dias_distintos = df_data['DT_DESPESA'].nunique()

print(f"Total de dias distintos em 2022: {total_dias_distintos}")
# Out:
# Total de dias distintos em 2022: 197

# %%
# Definindo o intervalo de datas desejado
start_date = "2022-08-16"
end_date = "2022-10-02"

# Filtrando o DataFrame para incluir apenas as datas dentro do intervalo
df_filtrado_2022 = df_filtrado[(df_filtrado['DT_DESPESA'] >= start_date) & (df_filtrado['DT_DESPESA'] <= end_date)]

# %%
color_map_manual = {
    ('Masculino', 'Fundo Especial de Financiamento de Campanha'): '#1f77b4',  # Azul
    ('Masculino', 'Fundo Partidário'): '#aec7e8',  # Azul claro
    ('Masculino', 'Outros Recursos'): '#ff7f0e',  # Laranja
    ('Feminino', 'Fundo Especial de Financiamento de Campanha'): '#ffbb78',  # Laranja claro
    ('Feminino', 'Fundo Partidárioa'): '#2ca02c',  # Verde
    ('Feminino', 'Outros Recursos'): '#98df8a'  # Verde claro
}

# Criando um DataFrame pivotado para o gráfico de área empilhada considerando 'DS_FONTE_DESPESA'
df_pivot = df_filtrado_2022.pivot_table(index='DT_DESPESA', columns=['DS_GENERO', 'DS_FONTE_DESPESA'], values='VR_DESPESA_CONTRATADA', aggfunc='sum')

# Criando o gráfico de área empilhada segmentado por gênero e fonte de despesa
fig, ax = plt.subplots(figsize=(12, 7))
df_pivot.plot(kind='area', stacked=True, ax=ax, alpha=0.9, color=[color_map_manual.get(col, '#d3d3d3') for col in df_pivot.columns])

# Configurando rótulos e título
ax.set_title('Despesas Contratadas por Gênero e Fonte ao Longo do Tempo')
ax.set_xlabel('Data da Despesa')
ax.set_ylabel('Valor da Despesa Contratada')
ax.legend(title='Gênero e Fonte de Despesa', loc='upper left', bbox_to_anchor=(1, 1))

# Exibir o gráfico no Colab
plt.show()

# %%
df_filtrado_2022.to_csv('../dados/base_dados_filtrada_U3.csv', index=False)

# %%
df_filtrado.to_csv('../dados/base_de_dados_tratada_U3.csv', index=False)
