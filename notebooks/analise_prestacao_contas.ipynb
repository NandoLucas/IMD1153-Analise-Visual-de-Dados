# %%
import pandas as pd

# Carregar o arquivo CSV
csv_file_path = "./despesas_pagas_candidatos_2022_RN.csv"
df = pd.read_csv(csv_file_path, sep=';', encoding='latin1')

# Exibir os dados
df.head()  # Exibe as primeiras 5 linhas
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  \
# 0  01/10/2024   02:00:54         2022                2       Ordinária
# 1  01/10/2024   02:00:54         2022                2       Ordinária
# 2  01/10/2024   02:00:54         2022                2       Ordinária
# 3  01/10/2024   02:00:54         2022                2       Ordinária
# 4  01/10/2024   02:00:54         2022                2       Ordinária
#
#    CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  ST_TURNO  \
# 0         546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 1         546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 2         546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 3         546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 4         546  Eleições Gerais Estaduais 2022  02/10/2022         1
#
#   TP_PRESTACAO_CONTAS  ...                              DS_ORIGEM_DESPESA  \
# ...

# %%
# Carregar o arquivo CSV
receitas = "./receitas_candidatos_2022_RN.csv"
df1 = pd.read_csv(receitas, sep=';', encoding='latin1')

# Exibir os dados
df1.head()  # Exibe as primeiras 5 linhas
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  \
# 0  01/10/2024   02:05:37         2022                2       ORDINÁRIA
# 1  01/10/2024   02:05:37         2022                2       ORDINÁRIA
# 2  01/10/2024   02:05:37         2022                2       ORDINÁRIA
# 3  01/10/2024   02:05:37         2022                2       ORDINÁRIA
# 4  01/10/2024   02:05:37         2022                2       ORDINÁRIA
#
#    CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  ST_TURNO  \
# 0         546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 1         546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 2         546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 3         546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 4         546  Eleições Gerais Estaduais 2022  02/10/2022         1
#
#   TP_PRESTACAO_CONTAS  ...              NM_PARTIDO_DOADOR  \
# 0               FINAL  ...  Partido Socialista Brasileiro
# ...
